# %% [markdown]
# # Lesson Title
#
# **Author:**
# **Date:**
# **Level:** Beginner/Intermediate

# %% [markdown]
# ## Introduction
#
# Provide a brief overview of what will be learned in this lesson. Start with a real-world context or motivation for the topic.

# %% [markdown]
# ## Theory
#
# Explain the key concepts and principles. Include mathematical formulations, algorithms, or foundational knowledge needed.

# %% [markdown]
# ## Imports and Setup

# %%
# Import necessary libraries
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %% [markdown]
# ## Visualization
#
# Demonstrate key concepts with visualizations.

# %%
# Visualization code here

# %% [markdown]
# ## Activity
#
# Hands-on exercise for learners to practice the concepts.

# %%
# Activity implementation

# %% [markdown]
# ## Key Takeaways
#
# - Summary point 1
# - Summary point 2
# - Summary point 3

# %% [markdown]
# ## Resources
#
# - [Resource 1](link)
# - [Resource 2](link)
# - [Resource 3](link)
